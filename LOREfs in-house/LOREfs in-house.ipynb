# %%
import deap
from functools import partial
from deap import base, creator, tools, algorithms
import random
import pandas as pd
import numpy as np
from deap import base, creator, tools, algorithms
from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import _tree

# %%
df=pd.read_csv('C:/Users/Gabriel/Pasta/Machine Learning/BINÁRIO_HRV.csv')

# %%
df
# Out:
#       CLASSE     IAH    T90  SATMIN  IDADE    ALTURA        PESO        IMC  \
# 0     NORMAL    3.07   0.03      87     35  1.660000   69.600000  25.257657
# 1     NORMAL    1.93   0.00      92     50  1.590000   98.700000  39.041177
# 2     NORMAL    0.40   0.00      92     27  1.800000   91.000000  28.086420
# 3     NORMAL    3.65   1.37      41     61  1.590000  103.700000  41.018947
# 4     NORMAL    1.15   0.07      88     26  1.649234   59.700000  21.948760
# ..       ...     ...    ...     ...    ...       ...         ...        ...
# 286  APNEICO  117.50  34.30      69     63  1.620000   89.500000  34.103033
# 287  APNEICO   72.00  68.40      67     64  1.640000  127.000000  47.218917
# 288  APNEICO   33.80   1.80      82     51  1.650000   94.200000  34.600551
# 289  APNEICO   34.30   4.60      83     59  1.649234   89.262007  32.817260
# 290  APNEICO   71.20  85.80      50     58  1.560000  116.000000  47.666009
#
#          PIP       W0  ...       AC       DC   PORTAS   GUZIKS  EHLERS  \
# 0    49.5922   4.0768  ... -11.9732  10.4526  46.6220  47.8699 -0.2132
# 1    48.4985   6.3788  ...  -6.3287   6.1144  49.2434  48.9933 -0.1273
# 2    51.0391  14.4829  ... -13.4549  14.9428  52.3657  57.2754  2.4017
# 3    60.8169   5.6235  ... -14.5812  14.4796  50.0457  50.2848  0.0960
# 4    47.7805   1.4780  ... -29.3785  35.4046  54.5368  56.3937  1.4414
# ..       ...      ...  ...      ...      ...      ...      ...     ...
# 286  54.1595  13.1081  ... -11.6846  10.8219  47.8445  48.0653 -0.2136
# 287  64.2736   1.0004  ...  -5.2141   7.1196  57.4381  57.5743  1.4235
# 288  48.8423   9.6049  ... -19.3183  21.7097  52.3061  56.6817  2.0795
# 289  62.6354   5.1821  ...  -3.5383   4.1281  52.1756  53.5385  0.7252
# 290  55.9210   9.5483  ... -17.3400  19.8391  52.8603  53.0188  0.6943
#
#        BIN0V    BIN1V    BIN2V    F    M
# 0    17.2253  68.7786  13.9962  1.0  0.0
# 1    24.8110  60.5646  14.6244  1.0  0.0
# 2    27.1533  51.4026  21.4442  0.0  1.0
# 3    11.2946  58.4855  30.2198  1.0  0.0
# 4    12.7135  79.9516   7.3349  1.0  0.0
# ..       ...      ...      ...  ...  ...
# 286  31.9158  46.3412  21.7430  1.0  0.0
# 287   9.6522  61.7281  28.6197  1.0  0.0
# 288  24.6303  59.7656  15.6041  0.0  1.0
# 289  21.7171  52.3949  25.8880  0.0  1.0
# 290  19.8313  55.8353  24.3334  1.0  0.0
#
# [291 rows x 44 columns]

# %%
#Separando conjunto de teste e de treino
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df, test_size=0.3, random_state=42)

# %%
train_set.iloc[:, 2:42]
# Out:
#        T90  SATMIN  IDADE  ALTURA   PESO        IMC      PIP       W0  \
# 258  23.60      75     67    1.61   76.0  29.319856  75.0727   4.2549
# 86   14.40      81     51    1.52   48.0  20.775623  69.9003   1.7170
# 229  10.80      77     70    1.64   69.0  25.654372  50.9938  12.7780
# 92    0.20      87     36    1.69   74.0  25.909457  54.0109   3.0068
# 97    1.40      83     27    1.55   70.0  29.136316  50.3281   5.6408
# ..     ...     ...    ...     ...    ...        ...      ...      ...
# 188  18.39      49     32    1.60  123.7  48.320312  52.5720   8.5143
# 71   18.70      73     56    1.56   85.0  34.927679  61.2185   3.0387
# 106   0.70      79     47    1.48   70.0  31.957633  58.2807   2.5312
# 270  99.70      53     40    1.85  188.0  54.930606  61.2457   4.1517
# 102  99.70      75     74    1.68   93.0  32.950680  74.1466   1.2692
#
#           W1       W2  ...   ATTEN  PHASEEN       AC       DC   PORTAS  \
# 258  11.3053  39.4062  ...  2.3475   0.6924  -1.2289   1.3699  51.0043
# 86   10.4227  64.2845  ...  1.4629   0.8812  -7.1137   6.5278  47.4961
# 229  34.7683  39.3050  ...  2.6883   0.9105  -9.6844   9.9350  51.1953
# 92   41.3305  46.3030  ...  1.9035   0.9189 -11.9485  10.7005  48.5700
# 97   50.0402  32.0461  ...  2.3812   0.9162  -6.2342   8.9840  51.3459
# ..       ...      ...  ...     ...      ...      ...      ...      ...
# 188  39.1033  38.5719  ...  2.4293   0.9233  -9.0357   8.4255  48.2910
# 71   20.9251  65.3840  ...  1.6233   0.9141 -11.6971  11.4989  49.8138
# 106  33.7759  50.0790  ...  1.9538   0.9216  -7.9992   7.7740  52.0880
# 270  27.5211  48.8306  ...  2.0666   0.9033  -5.0520   5.8209  52.2840
# 102  10.2672  53.2601  ...  1.6841   0.8706  -2.5366   3.6157  54.8450
#
#       GUZIKS  EHLERS    BIN0V    BIN1V    BIN2V
# 258  51.3277  0.2126  23.9461  42.7151  33.3388
# 86   46.7781 -0.5562   5.5659  56.1571  38.2771
# 229  50.8643  0.1930  31.9211  52.4566  15.6223
# 92   51.0898  0.2328  16.2400  69.8136  13.9465
# 97   52.4776  0.4417  29.3564  58.4494  12.1942
# ..       ...     ...      ...      ...      ...
# 188  49.9403 -0.0504  25.6497  54.3417  20.0087
# 71   51.2127  0.4347   9.1912  67.6111  23.1977
# 106  53.6257  0.7734  13.8376  66.4834  19.6790
# 270  52.9548  0.4492  16.9553  61.9908  21.0539
# 102  57.9662  1.9637   8.5135  51.1470  40.3395
#
# [203 rows x 40 columns]

# %%
from sklearn.experimental import enable_iterative_imputer
from imblearn.over_sampling import SMOTE
#Realiza o over-sampling
smote = SMOTE(random_state=7)
from sklearn.impute import IterativeImputer as imputer
X_T, y_T = smote.fit_resample(train_set.iloc[:, 2:42], train_set['CLASSE'],)
from collections import Counter
print(y_T.value_counts())
# Out:
# CLASSE
# APNEICO    129
# NORMAL     129
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier(random_state=7)
RF.fit(X_T,y_T)
# Out:
# RandomForestClassifier(random_state=7)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
y_t = test_set['CLASSE'].copy()
X_t = test_set.iloc[:, 2:42].copy()
print(y_t.value_counts())
predict=RF.predict(X_t)
accuracy_score(predict,y_t)
# Out:
# CLASSE
# APNEICO    52
# NORMAL     36
# Name: count, dtype: int64
# 0.7272727272727273

# %%
print(predict)
# Out:
# ['APNEICO' 'APNEICO' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO' 'APNEICO'
#  'APNEICO' 'NORMAL' 'APNEICO' 'NORMAL' 'APNEICO' 'NORMAL' 'APNEICO'
#  'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO'
#  'APNEICO' 'APNEICO' 'APNEICO' 'NORMAL' 'NORMAL' 'APNEICO' 'APNEICO'
#  'APNEICO' 'NORMAL' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO' 'APNEICO'
#  'APNEICO' 'APNEICO' 'NORMAL' 'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL'
#  'APNEICO' 'APNEICO' 'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO'
#  'NORMAL' 'APNEICO' 'NORMAL' 'NORMAL' 'APNEICO' 'NORMAL' 'APNEICO'
#  'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO' 'NORMAL'
#  'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO' 'NORMAL'
#  'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO' 'NORMAL' 'APNEICO' 'APNEICO'
#  'APNEICO' 'APNEICO' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO' 'NORMAL'
#  'APNEICO' 'NORMAL' 'NORMAL']

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

unique_labels = np.unique(y_t)
conf_matrix = confusion_matrix(y_t, predict, labels=unique_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=unique_labels)
disp.plot(cmap="Spectral", colorbar=False, values_format='d')
for text in disp.im_.axes.texts:
    text.set_color('black')
    text.set_fontsize(14)
plt.xlabel('Rótulos Previstos', fontsize=20)
plt.ylabel('Rótulos Verdadeiros', fontsize=20)
plt.show()

# %%
#Converter as linhas do DataFrame (excluindo a classe) em listas de características
colunas_features = X_t.columns
individuos_iniciais = X_t[colunas_features].values.tolist()
classes_iniciais = y_t.tolist()

#Cria a classe de aptidão e o indivíduo
creator.create("FitnessMax", base.Fitness, weights=(1.0,))  # Maximização
creator.create("Individual", list, fitness=creator.FitnessMax)

# %%
print(classes_iniciais)
# Out:
# ['NORMAL', 'APNEICO', 'NORMAL', 'APNEICO', 'APNEICO', 'APNEICO', 'APNEICO', 'APNEICO', 'NORMAL', 'NORMAL', 'APNEICO', 'APNEICO', 'NORMAL', 'APNEICO', 'APNEICO', 'NORMAL', 'NORMAL', 'NORMAL', 'APNEICO', 'APNEICO', 'APNEICO', 'APNEICO', 'APNEICO', 'NORMAL', 'NORMAL', 'APNEICO', 'APNEICO', 'NORMAL', 'NORMAL', 'APNEICO', 'NORMAL', 'NORMAL', 'APNEICO', 'APNEICO', 'NORMAL', 'APNEICO', 'APNEICO', 'APNEICO', 'APNEICO', 'NORMAL', 'APNEICO', 'NORMAL', 'APNEICO', 'APNEICO', 'APNEICO', 'NORMAL', 'NORMAL', 'NORMAL', 'APNEICO', 'APNEICO', 'APNEICO', 'NORMAL', 'NORMAL', 'APNEICO', 'APNEICO', 'APNEICO', 'APNEICO', 'APNEICO', 'NORMAL', 'APNEICO', 'APNEICO', 'APNEICO', 'NORMAL', 'NORMAL', 'APNEICO', 'APNEICO', 'NORMAL', 'NORMAL', 'APNEICO', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'APNEICO', 'NORMAL', 'NORMAL', 'APNEICO', 'APNEICO', 'APNEICO', 'NORMAL', 'APNEICO', 'APNEICO', 'APNEICO', 'APNEICO', 'APNEICO', 'APNEICO', 'NORMAL']

# %%
continuous = colunas_features
discrete=[]
class_name = 'CLASSE'
idx_features = colunas_features

min_vals = X_t[continuous].min().values
max_vals = X_t[continuous].max().values

# %%
def distance_function(x0d, x1d, discrete, continuous, class_name, min_vals, max_vals):
    #Converte dicionários em arrays
    u = np.array(list(x0d.values()))
    v = np.array(list(x1d.values()))

    # Normaliza os vetores (evita divisão por zero)
    denom = max_vals - min_vals
    denom[denom == 0] = 1  # Garante que não haja divisão por zero
    u_norm = (u - min_vals) / denom
    v_norm = (v - min_vals) / denom

    #Calcula o numerador (distância quadrada entre vetores normalizados)
    numerator = np.sum((u_norm - v_norm) ** 2)

    #Calcula o denominador (norma quadrada normalizada)
    denominator = np.sum(u_norm ** 2) + np.sum(v_norm ** 2)

    return numerator / denominator if denominator != 0 else 0.0

# %%
def fitness_sso_shared(x0, bb, alpha1, alpha2, eta, discrete, continuous, class_name, idx_features,
                       distance_function, x1, population, sig=1.0, beta=1.0):
    # Converter listas para dicionários com nomes das features
    x0d = {idx_features[i]: val for i, val in enumerate(x0)}
    x1d = {idx_features[i]: val for i, val in enumerate(x1)}
    
    # Similaridade entre as instâncias
    sim_ratio = 0.0 if x0d == x1d else 1.0
    
    record_similarity = 1.0 - distance_function(x0d, x1d, discrete, continuous, class_name, min_vals, max_vals)

    # Previsão com DataFrame nomeado
    x0_df = pd.DataFrame([x0], columns=idx_features)
    x1_df = pd.DataFrame([x1], columns=idx_features)

    y0 = bb.predict(x0_df)[0]
    y1 = bb.predict(x1_df)[0]
    
    # Similaridade de saída
    target_similarity = 1.0 if y0 == y1 else 0.0

    # Avaliação original (fitness antes do compartilhamento)
    raw_fitness_sso = float(sim_ratio) + float(alpha1) * float(record_similarity) + float(alpha2) * float(target_similarity)

    # --- FITNESS SHARING ---
    def sharing_function(d, sig, beta):
        return 1 - (d / sig) ** beta if d < sig else 0.0

    #Calcular soma das funções de compartilhamento com os outros indivíduos da população
    sharing_sum = 0.0
    for other in population:
        other_d = {idx_features[i]: val for i, val in enumerate(other[:len(idx_features)])}
        dist = distance_function(x0d, other_d, discrete, continuous, class_name, min_vals, max_vals)
        sharing_sum += sharing_function(dist, sig, beta)

    #Garantir que não dividimos por zero
    if sharing_sum == 0.0:
        sharing_sum = 1.0

    shared_fitness = raw_fitness_sso / sharing_sum
    
    return shared_fitness,
    
def fitness_sdo_shared(x0, bb, alpha1, alpha2, eta, discrete, continuous, class_name, idx_features,
                       distance_function, x1, population, sig=0.5, beta=1.0):
        # Converter listas para dicionários com nomes das features
    x0d = {idx_features[i]: val for i, val in enumerate(x0)}
    x1d = {idx_features[i]: val for i, val in enumerate(x1)}
    
    # Similaridade entre as instâncias
    sim_ratio = 0.0 if x0d == x1d else 1.0
    
    record_similarity = 1.0 - distance_function(x0d, x1d, discrete, continuous, class_name, min_vals, max_vals)

    # Previsão com DataFrame nomeado
    x0_df = pd.DataFrame([x0], columns=idx_features)
    x1_df = pd.DataFrame([x1], columns=idx_features)

    y0 = bb.predict(x0_df)[0]
    y1 = bb.predict(x1_df)[0]
    
    # Similaridade de saída
    target_similarity = 1.0 if y0 != y1 else 0.0

    # Avaliação original (fitness antes do compartilhamento)
    raw_fitness_sdo = float(sim_ratio) + float(alpha1) * float(record_similarity) + float(alpha2) * float(target_similarity)

    # --- FITNESS SHARING ---
    def sharing_function(d, sig, beta):
        return 1 - (d / sig) ** beta if d < sig else 0.0

    #Calcular soma das funções de compartilhamento com os outros indivíduos da população
    sharing_sum = 0.0
    for other in population:
        other_d = {idx_features[i]: val for i, val in enumerate(other[:len(idx_features)])}
        dist = distance_function(x0d, other_d, discrete, continuous, class_name, min_vals, max_vals)
        sharing_sum += sharing_function(dist, sig, beta)

    #Garantir que não dividimos por zero
    if sharing_sum == 0.0:
        sharing_sum = 1.0

    shared_fitness = raw_fitness_sdo / sharing_sum
    
    return shared_fitness,

# %%
#Reprodução, crossover do tipo aritmético
def Crossover_func(ind1, ind2, alpha=0.5, cx_prob=0.5):
    if random.random() < 1:
        for i, (x1, x2) in enumerate(zip(ind1[:-1], ind2[:-1])):  # Ignorar a última coluna (classe)
            gamma = (1. + 2. * alpha) * random.random() - alpha
            ind1[i] = (1. - gamma) * x1 + gamma * x2
            ind2[i] = gamma * x1 + (1. - gamma) * x2
        
        #Manter a classe original dos indivíduos sem alterar
        ind1[-1] = ind1[-1]  #A classe de ind1 permanece inalterada
        ind2[-1] = ind2[-1]  #A classe de ind2 permanece inalterada
        
        return ind1, ind2
    else:
        return ind1, ind2

# %%
#Mutação
#mu é a média da distribuição gaussiana e sigma o desvio padrão
def mutGaussianWithoutClass(individual, mu, sigma, mutpb, min_vals=min_vals, max_vals=max_vals):
    # Aplica mutação apenas às características numéricas, ignorando a última posição (classe)
    for i in range(len(individual) - 1):  # Ignorar a última coluna (classe)
        if random.random() < 1:
            individual[i] += random.gauss(mu, sigma)  # Aplica a mutação nas características numéricas
            
            # Aplica o clipping se min_vals e max_vals forem fornecidos
            if min_vals is not None and max_vals is not None:
                individual[i] = np.clip(individual[i], min_vals[i], max_vals[i])

    return individual,  # Retorna o indivíduo como tupla

# %%
def get_decision_path(ClassificadorDT, xi_df, feature_names):
    """
    Retorna um dicionário com os nós percorridos e as decisões tomadas.
    """
    node_indicator = ClassificadorDT.decision_path(xi_df)
    leaf_id = ClassificadorDT.apply(xi_df)[0]  # Nó final

    feature = ClassificadorDT.tree_.feature
    threshold = ClassificadorDT.tree_.threshold

    decision_dict = {}
    xi_array = xi_df.values  # para acessar os valores numéricos

    for node_id in node_indicator.indices:
        if leaf_id == node_id:
            decision_dict[f"Nó {node_id}"] = "Folha"
        else:
            feature_index = feature[node_id]
            threshold_value = threshold[node_id]
            feature_name = feature_names[feature_index]
            sample_value = xi_array[0, feature_index]  # aqui pode usar vírgula

            decision = f"{feature_name} <= {threshold_value}" if sample_value <= threshold_value else f"{feature_name} > {threshold_value}"
            decision_dict[f"Nó {node_id}"] = decision

    return decision_dict

# %%
import time  
tempo_total_inicio = time.time()  #Início do tempo total

# %%
for idx in range(len(individuos_iniciais)):
    tempo_inicio = time.time()  #Início do tempo da iteração
    def ordinal_pt(n):
        sufixos = ["primeira", "segunda", "terceira", "quarta", "quinta", "sexta",
                   "sétima", "oitava", "nona", "décima"]
        if 0 <= n < len(sufixos):
            return sufixos[n]
        else:
            return f"{n+1}ª"

    print(f"\nGerando os Dados para a {ordinal_pt(idx)} Explicação")
    
    def create_individual():
        return individuos_iniciais[idx] + [classes_iniciais[idx]]  
    
    #Criando indivíduos que estão próximos e resultam na mesma classe SSO
    individuo_inicial = individuos_iniciais[idx] 
    xi=individuo_inicial
    
    print("\nIndivíduo sendo explicado", xi)
    def evaluate(individual):
        #Parâmetros da função de fitness
        alpha1 = 0.5
        alpha2 = 0.5
        eta = 0.6
        discrete = []
        continuous = colunas_features
        class_name = 'CLASSE'
        idx_features = colunas_features
        #Avaliar usando a função fitness_sso
        return fitness_sso_shared(individual[:40], RF, alpha1, alpha2, eta, discrete, continuous, class_name, idx_features, distance_function, xi, population, sig=0.2, beta=1.0)
    
    #Configuração da toolbox do DEAP
    toolbox = base.Toolbox()
    toolbox.register("individual", tools.initIterate, creator.Individual, create_individual)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)
    toolbox.register("mate", Crossover_func, alpha=0.5, cx_prob=0.5)
    toolbox.register("mutate", mutGaussianWithoutClass, mu=0, sigma=1, mutpb=0.3)
    toolbox.register("select", tools.selTournament, tournsize=3)
    toolbox.register("evaluate", evaluate)  # Passar o indivíduo inicial aqui
    
    #Criando a população inicial e estabelecendo os parâmetros do AG
    population = toolbox.population(n=500)
    ngen = 10
    cxpb, mutpb = 0.5, 0.3  #Probabilidades de cruzamento e mutação
    
    #Executando o algoritmo genético
    result, log = algorithms.eaSimple(population, toolbox, cxpb, mutpb, ngen, verbose=False)
    
    #Exibindo o melhor indivíduo gerado
    best_individual = tools.selBest(population, 1)[0]
    print(f"\nMelhor indivíduo SSO: {best_individual}, Fitness: {best_individual.fitness.values}")
    
    #Armazenando os indivíduos gerados
    novos_individuos_SSO = [ind[:40] for ind in population]  

    #Criando indivíduos que estão próximos mas resultam numa classe diferente SDO
    individuo_inicial = individuos_iniciais[idx] 
    xi=individuo_inicial
    
    def evaluate(individual):
        # Parâmetros da função de fitness
        alpha1 = 0.5
        alpha2 = 0.5
        eta = 0.6
        discrete = []
        continuous = colunas_features
        class_name = 'CLASSE'
        idx_features = colunas_features
        # Avaliar usando a função fitness_sdo
        return fitness_sdo_shared(individual[:40], RF, alpha1, alpha2, eta, discrete, continuous, class_name, idx_features, distance_function, xi, population, sig=0.2, beta=1.0)
    
    #Configuração da toolbox do DEAP
    toolbox = base.Toolbox()
    toolbox.register("individual", tools.initIterate, creator.Individual, create_individual)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)
    toolbox.register("mate", Crossover_func, alpha=0.5, cx_prob=0.5)
    toolbox.register("mutate", mutGaussianWithoutClass, mu=0, sigma=1, mutpb=0.3)
    toolbox.register("select", tools.selTournament, tournsize=3)
    toolbox.register("evaluate", evaluate)  # Passar o indivíduo inicial aqui
    
    #Criando a população inicial e estabelecendo os parâmetros do AG
    population = toolbox.population(n=500)
    ngen = 10 
    cxpb, mutpb = 0.5, 0.3 #Definidos dentro do eaSimple
    
    #Executando o algoritmo genético
    result, log = algorithms.eaSimple(population, toolbox, cxpb, mutpb, ngen, verbose=False)
    
    #Exibindo o melhor resultado
    best_individual = tools.selBest(population, 1)[0]
    print(f"\nMelhor indivíduo SDO: {best_individual[:-1]}, Fitness: {best_individual.fitness.values}")
    
    #Armazenando os individuos SDO gerados
    novos_individuos_SDO= [ind[:40] for ind in population]

    SSO=pd.DataFrame(novos_individuos_SSO)
    SDO=pd.DataFrame(novos_individuos_SDO)
    XSSO=SSO.iloc[:, :40].values
    XSDO=SDO.iloc[:, :].values

    XTOTAL = pd.concat([SSO, SDO], ignore_index=True)
    XTOTAL_df = pd.DataFrame(XTOTAL.to_numpy(), columns=X_t.columns)

    ytotal= RF.predict(XTOTAL_df)
    pd.Series(ytotal).value_counts()

    y_series = pd.Series(ytotal, name="label")
    dfb= XTOTAL_df.copy()
    dfb["label"] = y_series
    
    #Descobre o tamanho da menor classe
    min_count = y_series.value_counts().min()
    
    #Balanceia o conjunto total
    balanced_df = dfb.groupby("label").sample(n=min_count, random_state=40)
    
    #print("\nConjunto de Dados Artificiais Gerados", balanced_df)
    
    #Separa novamente X e y
    Xb = balanced_df.drop(columns="label")
    yb = balanced_df["label"] 

    ClassificadorDT = DecisionTreeClassifier(max_depth=15, random_state=7)
    ClassificadorDT.fit(Xb, yb)
    
    print(f"\nGerando a {ordinal_pt(idx)} Explicação")
    
    xi = np.array(xi).reshape(1, -1)  
    xi_df = pd.DataFrame(xi, columns=colunas_features)
    
    Explicando=ClassificadorDT.predict(xi_df)
    print("\nPor que o indivíduo foi classificado como:", Explicando, '?')

    node_indicator = ClassificadorDT.decision_path(xi_df)
    node_index = node_indicator.indices
    print("\nPorque o seguintes nós foram percorridos para essa amostra:")
    
    thresholds = ClassificadorDT.tree_.threshold
    features = ClassificadorDT.tree_.feature
    children_left = ClassificadorDT.tree_.children_left
    children_right = ClassificadorDT.tree_.children_right
    
    explicacoes_nos = []

    for node_id in node_index:
        f_index = features[node_id]      # índice da feature usada no nó
        thresh = thresholds[node_id]     # limiar do nó
    
        if f_index >= 0:
            val = xi[0][f_index]
            feature_name = xi_df.columns[f_index]
            cond = "SATISFEITA" if val <= thresh else "NÃO SATISFEITA"
            explicacao = f"Nó {node_id}: {feature_name} = {val:.3f}, condição testada: {feature_name} <= {thresh:.3f} → {cond}"
        else:
            explicacao = f"Nó {node_id}: folha alcançada, o indivíduo é: {Explicando}"
    
        print(explicacao)
        explicacoes_nos.append(explicacao)
            
    feature_names_exp = colunas_features
    Explicacao = get_decision_path(ClassificadorDT, xi_df, feature_names_exp)
    print(f"\nExplicação para a {ordinal_pt(idx)} instância de X_t", Explicacao)

    #Salvando a explicação dos nós percorridos
    with open(f"exp_premissas fs/explicacao_nos_amostra_{idx}.txt", "w", encoding="utf-8") as f_nos:
        f_nos.write("\n".join(explicacoes_nos))
    
    #Salvando a explicação do caminho da árvore num formato mais parecido com o dicionário do LORE
    with open(f"exp_final fs/explicacao_final_amostra_{idx}.txt", "w", encoding="utf-8") as f_final:
        for chave, valor in Explicacao.items():
            f_final.write(f"{chave}: {valor}\n")
    
    tempo_fim = time.time()  #Fim do tempo de uma iteração
    print(f"\n⏱️ Tempo de execução da {ordinal_pt(idx)} explicação: {tempo_fim - tempo_inicio:.2f} segundos")

tempo_total_fim = time.time()  #Fim do tempo total
print(f"\n✅ Tempo total de execução: {tempo_total_fim - tempo_total_inicio:.2f} segundos")
# Out:
# Gerando os Dados para a primeira Explicação
#
# Indivíduo sendo explicado [0.0, 90.0, 42.0, 1.61, 108.0, 41.66505921839435, 54.4808, 6.0207, 38.3577, 41.824, 13.7975, 56.7664, 36.2767, 1.4186, 5.5382, 445.0917, 135.8711, 57.4757, 66.9582, 33.0418, 2.2287, 743.2054, 35.2199, 11.7962, 1.4613, 1.522, 1.0348, 0.5647, 2.4223, 3.6904, 2.4321, 0.9088, -6.1145, 6.4501, 51.3422, 52.2414, 0.4297, 27.6741, 59.3422, 12.9837]
#
# Melhor indivíduo SSO: [np.float64(2.3204801358502243), np.float64(89.07124903277153), np.float64(41.34462312956754), np.float64(1.174055086936765), np.float64(108.06750465424244), np.float64(40.96128949945627), np.float64(56.18810137248503), np.float64(10.688815239981137), np.float64(40.50650163905045), np.float64(42.32145434866016), np.float64(13.680102908278506), np.float64(47.180263141331224), np.float64(34.60481159356427), np.float64(1.691493670552247), np.float64(5.9988344310095805), np.float64(445.48667730840924), np.float64(136.78878906758987), np.float64(57.043317259262224), np.float64(68.48207873733114), np.float64(32.644872430187604), np.float64(4.3944257045575545), np.float64(742.0930000722107), np.float64(33.28542612182963), np.float64(12.681031310407416), np.float64(-0.028707119163738692), np.float64(-1.7084475426054744), np.float64(0.8539583540067266), np.float64(-0.04169543673950483), np.float64(2.9411592846797587), np.float64(5.917474912894513), np.float64(1.55595232448955), np.float64(0.8560509315024882), np.float64(-5.683222794267984), np.float64(8.170271122417443), np.float64(52.72559997281034), np.float64(54.92909283675088), np.float64(-1.0086851172978144), np.float64(28.69780684464193), np.float64(57.976621861154726), np.float64(11.638536541808616), 'NORMAL'], Fitness: (np.float64(311.74835135891345),)
#
# Melhor indivíduo SDO: [np.float64(-0.08643068802351116), np.float64(86.74749519670056), np.float64(42.63375342425158), np.float64(1.1248045099941515), np.float64(107.92224513480174), np.float64(39.58600653125899), np.float64(54.76414723954103), np.float64(4.651889813792298), np.float64(37.86344910728765), np.float64(40.34565019187578), np.float64(12.15689329890037), np.float64(56.825007815332825), np.float64(35.7417150781278), np.float64(5.435359477199246), np.float64(5.417258245617265), np.float64(446.7458046001682), np.float64(135.0544599992378), np.float64(57.07913604336978), np.float64(66.57972329920068), np.float64(34.856058392735186), np.float64(3.0597166164671368), np.float64(740.2003401398854), np.float64(35.22274356816028), np.float64(11.901841138596312), np.float64(-0.3673574859845529), np.float64(4.1229927313859465), np.float64(0.6092639934928002), np.float64(-0.18019890722786533), np.float64(2.469816647724796), np.float64(4.873238574370943), np.float64(2.48871842032595), np.float64(0.6782360685158123), np.float64(-6.7631072742066225), np.float64(5.713727979980902), np.float64(52.87375973231202), np.float64(56.79125179401079), np.float64(5.530475844026084), np.float64(25.397954552487356), np.float64(59.21149946356968), np.float64(14.031328543174851)], Fitness: (np.float64(37.8424072494658),)
#
# Gerando a primeira Explicação
#
# Por que o indivíduo foi classificado como: ['NORMAL'] ?
#
# Porque o seguintes nós foram percorridos para essa amostra:
# Nó 0: T90 = 0.000, condição testada: T90 <= 1.009 → SATISFEITA
# Nó 1: ATTEN = 2.432, condição testada: ATTEN <= 2.336 → NÃO SATISFEITA
# Nó 65: SAMPEN = 1.522, condição testada: SAMPEN <= 1.319 → NÃO SATISFEITA
# Nó 89: MEANRR = 743.205, condição testada: MEANRR <= 745.020 → SATISFEITA
# Nó 90: BIN1V = 59.342, condição testada: BIN1V <= 58.154 → NÃO SATISFEITA
# Nó 98: PORTAS = 51.342, condição testada: PORTAS <= 52.451 → SATISFEITA
# Nó 99: PORTAS = 51.342, condição testada: PORTAS <= 48.379 → NÃO SATISFEITA
# Nó 101: folha alcançada, o indivíduo é: ['NORMAL']
#
# Explicação para a primeira instância de X_t {'Nó 0': 'T90 <= 1.0091037154197693', 'Nó 1': 'ATTEN > 2.3356192111968994', 'Nó 65': 'SAMPEN > 1.31887286901474', 'Nó 89': 'MEANRR <= 745.0198364257812', 'Nó 90': 'BIN1V > 58.153846740722656', 'Nó 98': 'PORTAS <= 52.45052146911621', 'Nó 99': 'PORTAS > 48.378944396972656', 'Nó 101': 'Folha'}
#
# ⏱️ Tempo de execução da primeira explicação: 171.18 segundos
explicação
#
# Por que o indivíduo foi classificado como: ['APNEICO'] ?
#
# Porque o seguintes nós foram percorridos para essa amostra:
# Nó 0: T90 = 2.400, condição testada: T90 <= 1.200 → NÃO SATISFEITA
# Nó 28: IDADE = 54.000, condição testada: IDADE <= 53.058 → NÃO SATISFEITA
# Nó 72: PHASEEN = 0.906, condição testada: PHASEEN <= 0.903 → NÃO SATISFEITA
# Nó 170: LFNU = 64.052, condição testada: LFNU <= 66.965 → SATISFEITA
# Nó 171: LFABS = 142.475, condição testada: LFABS <= 145.422 → SATISFEITA
# Nó 172: SDNN = 30.154, condição testada: SDNN <= 23.788 → NÃO SATISFEITA
# Nó 174: BIN0V = 23.527, condição testada: BIN0V <= 29.347 → SATISFEITA
# Nó 175: SAMPEN = 1.778, condição testada: SAMPEN <= 5.804 → SATISFEITA
# Nó 176: ATTEN = 2.381, condição testada: ATTEN <= 0.411 → NÃO SATISFEITA
# Nó 182: GUZIKS = 51.414, condição testada: GUZIKS <= 47.930 → NÃO SATISFEITA
# Nó 186: DISPEN = 3.986, condição testada: DISPEN <= 1.769 → NÃO SATISFEITA
# Nó 190: folha alcançada, o indivíduo é: ['APNEICO']
#
# Explicação para a segunda instância de X_t {'Nó 0': 'T90 > 1.2001855373382568', 'Nó 28': 'IDADE > 53.05754470825195', 'Nó 72': 'PHASEEN > 0.9025968611240387', 'Nó 170': 'LFNU <= 66.96469497680664', 'Nó 171': 'LFABS <= 145.42156982421875', 'Nó 172': 'SDNN > 23.788289070129395', 'Nó 174': 'BIN0V <= 29.34711456298828', 'Nó 175': 'SAMPEN <= 5.804131269454956', 'Nó 176': 'ATTEN > 0.41062571108341217', 'Nó 182': 'GUZIKS > 47.929874420166016', 'Nó 186': 'DISPEN > 1.7689916491508484', 'Nó 190': 'Folha'}
#
# ⏱️ Tempo de execução da segunda explicação: 171.94 segundos
#
# Gerando os Dados para a terceira Explicação
#
# Indivíduo sendo explicado [2.0, 82.0, 53.0, 1.64, 65.0, 24.167162403331357, 58.2716, 5.4463, 29.4046, 50.0357, 15.1134, 40.1334, 43.4383, 3.6683, 12.7601, 427.9893, 193.095, 113.0264, 59.1798, 40.8202, 1.7576, 961.6866, 42.0937, 19.5075, 1.3491, 1.7129, 1.4049, 0.5993, 2.5162, 4.1768, 2.0785, 0.9211, -7.5442, 7.9502, 51.4894, 51.6891, 0.414, 17.6156, 60.0317, 22.3527]
#
# Melhor indivíduo SSO: [np.float64(1.8307027038306003), np.float64(77.56200656681291), np.float64(47.940702206247565), np.float64(1.3624339211984247), np.float64(66.03526156374362), np.float64(24.408247458772685), np.float64(58.11216073841054), np.float64(5.452241089330307), np.float64(34.84129872904789), np.float64(56.8443129551012), np.float64(14.712330568940155), np.float64(39.19165081869929), np.float64(42.88212058413866), np.float64(6.657523196532698), np.float64(14.519614377348216), np.float64(427.2370884444534), np.float64(192.9097509207352), np.float64(110.54617203790185), np.float64(58.335186276203515), np.float64(45.81642827043855), np.float64(2.014098018893158), np.float64(961.8207724509266), np.float64(41.853376834017574), np.float64(19.967484927650695), np.float64(1.9197423864601297), np.float64(0.8720861332629273), np.float64(0.8472137474235898), np.float64(0.7398592157529599), np.float64(2.175576611340089), np.float64(9.715879035144123), np.float64(1.8603827493531349), np.float64(0.8782694606350194), np.float64(-9.264551740261052), np.float64(6.08419778393801), np.float64(51.62907634560171), np.float64(50.696233643862925), np.float64(-8.721779014187208), np.float64(13.896901708534378), np.float64(57.02576495010651), np.float64(21.053454629257004), 'NORMAL'], Fitness: (np.float64(197.76314009027982),)
#
# Melhor indivíduo SDO: [np.float64(2.3318121312705458), np.float64(83.25793670450787), np.float64(60.34604749771265), np.float64(1.956394338491904), np.float64(64.1197375607191), np.float64(25.19511786725426), np.float64(59.81162219514164), np.float64(5.541841178599204), np.float64(32.63646725638484), np.float64(52.107566127939194), np.float64(12.70262788868887), np.float64(34.80589084645895), np.float64(44.5944947762012), np.float64(5.165209612096447), np.float64(13.123241539276027), np.float64(428.6156256768966), np.float64(193.60391057964398), np.float64(112.6170587945472), np.float64(59.712348651110865), np.float64(36.54461046384469), np.float64(1.9427445142236315), np.float64(960.4450495687713), np.float64(42.31465530748371), np.float64(16.182169365721712), np.float64(0.9938383529783843), np.float64(-1.3819190669717898), np.float64(0.6398724264164702), np.float64(1.2017099669516307), np.float64(2.152353858873467), np.float64(1.2655690946524671), np.float64(2.791642975832388), np.float64(1.007020255550131), np.float64(-7.006317532318057), np.float64(7.795948616096334), np.float64(49.291037643487726), np.float64(51.22753696566757), np.float64(4.61961077160584), np.float64(16.326590251361765), np.float64(59.88717581002815), np.float64(24.889328655727)], Fitness: (np.float64(62.76222502970236),)
#
# Gerando a terceira Explicação
#
# Por que o indivíduo foi classificado como: ['NORMAL'] ?
#
# Porque o seguintes nós foram percorridos para essa amostra:
# Nó 0: PHASEEN = 0.921, condição testada: PHASEEN <= 0.922 → SATISFEITA
# Nó 1: IDADE = 53.000, condição testada: IDADE <= 53.202 → SATISFEITA
# Nó 2: DFA  = 1.349, condição testada: DFA  <= 2.558 → SATISFEITA
# Nó 3: SATMIN = 82.000, condição testada: SATMIN <= 77.928 → NÃO SATISFEITA
# Nó 7: PORTAS = 51.489, condição testada: PORTAS <= 47.694 → NÃO SATISFEITA
# Nó 11: W3 = 15.113, condição testada: W3 <= 13.942 → NÃO SATISFEITA
# Nó 25: SDNN = 42.094, condição testada: SDNN <= 35.552 → NÃO SATISFEITA
# Nó 29: MEANRR = 961.687, condição testada: MEANRR <= 956.898 → NÃO SATISFEITA
# Nó 31: SYMB2UV = 12.760, condição testada: SYMB2UV <= 9.351 → NÃO SATISFEITA
# Nó 35: LFABS = 193.095, condição testada: LFABS <= 195.453 → SATISFEITA
# Nó 36: PIP = 58.272, condição testada: PIP <= 54.703 → NÃO SATISFEITA
# Nó 38: PIP = 58.272, condição testada: PIP <= 66.222 → SATISFEITA
# Nó 39: T90 = 2.000, condição testada: T90 <= 5.780 → SATISFEITA
# Nó 40: LFABS = 193.095, condição testada: LFABS <= 188.220 → NÃO SATISFEITA
# Nó 42: LFNU = 59.180, condição testada: LFNU <= 54.922 → NÃO SATISFEITA
# Nó 44: folha alcançada, o indivíduo é: ['NORMAL']
#
# Explicação para a terceira instância de X_t {'Nó 0': 'PHASEEN <= 0.9219394028186798', 'Nó 1': 'IDADE <= 53.201555252075195', 'Nó 2': 'DFA  <= 2.557604432106018', 'Nó 3': 'SATMIN > 77.92837142944336', 'Nó 7': 'PORTAS > 47.69416427612305', 'Nó 11': 'W3 > 13.941642761230469', 'Nó 25': 'SDNN > 35.55224800109863', 'Nó 29': 'MEANRR
explicação
#
# Por que o indivíduo foi classificado como: ['APNEICO'] ?
#
# Porque o seguintes nós foram percorridos para essa amostra:
# Nó 0: DISPEN = 3.727, condição testada: DISPEN <= 4.497 → SATISFEITA
# Nó 1: DISTEN = 0.590, condição testada: DISTEN <= 0.927 → SATISFEITA
# Nó 2: BIN1V = 47.433, condição testada: BIN1V <= 50.832 → SATISFEITA
# Nó 3: ATTEN = 3.068, condição testada: ATTEN <= 6.108 → SATISFEITA
# Nó 4: W1 = 36.029, condição testada: W1 <= 32.203 → NÃO SATISFEITA
# Nó 6: LFNU = 83.793, condição testada: LFNU <= 79.385 → NÃO SATISFEITA
# Nó 10: folha alcançada, o indivíduo é: ['APNEICO']
#
# Explicação para a sexta instância de X_t {'Nó 0': 'DISPEN <= 4.497069835662842', 'Nó 1': 'DISTEN <= 0.9265616834163666', 'Nó 2': 'BIN1V <= 50.831939697265625', 'Nó 3': 'ATTEN <= 6.108091115951538', 'Nó 4': 'W1 > 32.20269966125488', 'Nó 6': 'LFNU > 79.38522720336914', 'Nó 10': 'Folha'}
#
# ⏱️ Tempo de execução da sexta explicação: 166.84 segundos
#
# Gerando os Dados para a sétima Explicação
#
# Indivíduo sendo explicado [12.2, 83.0, 36.0, 1.79, 86.0, 26.840610467838083, 46.0106, 7.2843, 55.1411, 29.8573, 7.7173, 27.5666, 48.653, 12.1795, 11.6009, 644.2791, 209.6136, 346.5123, 34.7118, 65.2882, 0.7251, 858.1975, 41.7969, 25.6287, 0.9111, 1.6424, 1.5162, 0.5908, 2.3533, 4.3519, 2.2238, 0.9384, -14.5471, 11.9812, 45.0479, 45.0, -0.8038, 28.9931, 62.3928, 8.6141]
#
# Melhor indivíduo SSO: [np.float64(10.70022534010548), np.float64(83.84657035982302), np.float64(37.27700924932715), np.float64(1.4172279102787948), np.float64(87.01937685397445), np.float64(27.298389811409923), np.float64(43.40277423326851), np.float64(7.867927022803324), np.float64(55.28213718987475), np.float64(30.563055135292615), np.float64(8.45453594854189), np.float64(27.30056607711073), np.float64(52.17548815782567), np.float64(14.737744563326531), np.float64(11.32214364346882), np.float64(646.8722848684721), np.float64(209.9231686291188), np.float64(349.5273756602588), np.float64(35.04824090258418), np.float64(65.35470943512401), np.float64(0.7492458015259855), np.float64(859.075090861849), np.float64(41.209988588857144), np.float64(24.521651952587305), np.float64(-2.1337239938457015), np.float64(1.2753925648591196), np.float64(0.428189891960165), np.float64(0.14114162909649453), np.float64(2.6170575570281356), np.float64(5.002498193909181), np.float64(1.4552192660528818), np.float64(0.6811702104243449), np.float64(-13.579495804340672), np.float64(10.051861118450876), np.float64(43.62400591882037), np.float64(46.31419470867873), np.float64(-2.792620707117971), np.float64(28.858084423579964), np.float64(63.698212440476375), np.float64(9.816942836707113), 'APNEICO'], Fitness: (np.float64(170.64411974282152),)
#
#
# Melhor indivíduo SDO: [np.float64(1.8285364492140321), np.float64(88.74065239671008), np.float64(22.968211240447907), np.float64(1.2183379864777681), np.float64(80.59099740718975), np.float64(34.865194439897955), np.float64(54.2116829793162), np.float64(0.7848482087795631), np.float64(41.89861570853695), np.float64(52.61045764223244), np.float64(4.5943919785853495), np.float64(4.697406828041466), np.float64(44.78338102771696), np.float64(24.877798097927425), np.float64(28.507513224150184), np.float64(177.2312014066885), np.float64(195.61222332489933), np.float64(1623.3202772501206), np.float64(21.232709471422943), np.float64(78.98850632056106), np.float64(3.8599189901926385), np.float64(786.4050133785322), np.float64(49.400736815013715), np.float64(62.08795442059216), np.float64(1.8444626727263032), np.float64(-1.7962533716238962), np.float64(1.3145064688382875), np.float64(0.5180099042898576), np.float64(2.9005680590375467), np.float64(3.3894079739910277), np.float64(1.584921354046239), np.float64(0.627880977225725), np.float64(-27.940661638721416), np.float64(18.866400918957254), np.float64(47.495683705218084), np.float64(55.47307769953796), np.float64(0.1719573225088623), np.float64(12.924184390465916), np.float64(67.52618600066562), np.float64(15.575320976214186)], Fitness: (np.float64(100.20536937984693),)
#
# Gerando a nona Explicação
#
# Por que o indivíduo foi classificado como: ['NORMAL'] ?
#
# Porque o seguintes nós foram percorridos para essa amostra:
# Nó 0: PHASEEN = 0.886, condição testada: PHASEEN <= 0.932 → SATISFEITA
# Nó 1: IMC = 32.861, condição testada: IMC <= 34.704 → SATISFEITA
# Nó 2: T90 = 0.100, condição testada: T90 <= 2.180 → SATISFEITA
# Nó 3: ATTEN = 1.448, condição testada: ATTEN <= 2.096 → SATISFEITA
# Nó 4: DFA  = 0.413, condição testada: DFA  <= 1.253 → SATISFEITA
# Nó 5: ALTURA = 1.570, condição testada: ALTURA <= 2.312 → SATISFEITA
# Nó 6: HFNU = 79.910, condição testada: HFNU <= 71.015 → NÃO SATISFEITA
# Nó 8: DFA  = 0.413, condição testada: DFA  <= -3.546 → NÃO SATISFEITA
# Nó 10: LFNU = 20.090, condição testada: LFNU <= 24.409 → SATISFEITA
# Nó 11: W1 = 42.539, condição testada: W1 <= 44.472 → SATISFEITA
# Nó 12: folha alcançada, o indivíduo é: ['NORMAL']
#
# Explicação para a nona instância de X_t {'Nó 0': 'PHASEEN <= 0.9323765337467194', 'Nó 1': 'IMC <= 34.70361328125', 'Nó 2': 'T90 <= 2.1803654432296753', 'Nó 3': 'ATTEN <= 2.095770001411438', 'Nó 4': 'DFA  <= 1.2527203559875488', 'Nó 5': 'ALTURA <= 2.31186044216156', 'Nó 6': 'HFNU > 71.0145378112793', 'Nó 8': 'DFA  > -3.546217679977417', 'Nó 10': 'LFNU <= 24.408660888671875', 'Nó 11': 'W1 <= 44.471744537353516', 'Nó 12': 'Folha'}
#
# ⏱️ Tempo de execução da nona explicação: 164.13 segundos
#
# Gerando os Dados para a décima Explicação
#
explicação
#
# Por que o indivíduo foi classificado como: ['APNEICO'] ?
#
# Porque o seguintes nós foram percorridos para essa amostra:
# Nó 0: folha alcançada, o indivíduo é: ['APNEICO']
#
# Explicação para a 12ª instância de X_t {'Nó 0': 'Folha'}
#
# ⏱️ Tempo de execução da 12ª explicação: 173.55 segundos
#
# Gerando os Dados para a 13ª Explicação
#
# Indivíduo sendo explicado [2.6, 86.0, 42.0, 1.75, 71.0, 23.18367346938776, 55.2536, 1.552, 35.4929, 58.6212, 4.3339, 9.1905, 47.9083, 16.4653, 26.4359, 186.4463, 174.5604, 594.9026, 21.9513, 78.0487, 0.2998, 994.737, 42.0033, 39.4742, 0.8455, 1.8164, 1.8811, 0.6081, 2.4828, 4.7161, 1.4072, 0.9142, -16.7508, 13.3917, 44.25, 44.0402, -0.9877, 8.7105, 76.6506, 14.6389]
#
# ...
# Nó 2: folha alcançada, o indivíduo é: ['NORMAL']
#
# Explicação para a 84ª instância de X_t {'Nó 0': 'DISTEN > 0.5773968994617462', 'Nó 2': 'Folha'}
#
# ⏱️ Tempo de execução da 84ª explicação: 164.82 segundos
#
# Gerando os Dados para a 85ª Explicação
#
# Indivíduo sendo explicado [0.66, 77.0, 38.0, 1.71, 112.0, 38.30238363941042, 58.8936, 1.879, 22.8335, 72.0267, 3.2608, 10.7555, 48.642, 11.6625, 28.94, 220.8339, 359.6869, 442.9024, 38.4335, 61.5665, 0.9999, 929.1243, 38.9529, 36.5068, 0.9845, 2.0498, 1.8762, 0.8044, 2.5414, 4.8758, 1.3269, 0.9037, -12.1727, 10.6368, 46.8407, 47.1754, -0.4222, 4.8753, 73.8015, 21.3232]
#
# Melhor indivíduo SSO: [np.float64(1.5161694431233002), np.float64(76.49716680306327), np.float64(37.38647585308728), np.float64(1.6780012024202033), np.float64(112.92810525018196), np.float64(39.950848606805735), np.float64(58.97768148278041), np.float64(2.8491383619266895), np.float64(22.746394760361078), np.float64(70.72897794269048), np.float64(1.616185231105814), np.float64(11.136482196479067), np.float64(47.9108322399106), np.float64(10.272950315851526), np.float64(28.14873012859615), np.float64(221.6640979371512), np.float64(362.9479016632319), np.float64(448.61715242100206), np.float64(39.71406893301328), np.float64(59.990320183024274), np.float64(-0.7368905500707351), np.float64(929.1794581612372), np.float64(36.69390919177065), np.float64(33.48774752336322), np.float64(0.08837879736462995), np.float64(6.657603399029518), np.float64(-0.23551392197022394), np.float64(0.7491180676847867), np.float64(1.7231138604114715), np.float64(4.099656336599704), np.float64(5.851195581505464), np.float64(0.9104765815092635), np.float64(-10.92569376646941), np.float64(11.827704846906213), np.float64(45.83022579924748), np.float64(44.289229165882915), np.float64(2.155886787186093), np.float64(6.692716508150429), np.float64(72.37136535284792), np.float64(25.43305846002192), 'APNEICO'], Fitness: (np.float64(75.58978937975564),)
#
# Melhor indivíduo SDO: [np.float64(1.4366061494617162), np.float64(76.93279899146869), np.float64(39.20929314959973), np.float64(1.990617856968115), np.float64(114.73754070929107), np.float64(37.58227845896991), np.float64(62.8500072600473), np.float64(5.259847541502157), np.float64(22.094104067041314), np.float64(71.58060395131216), np.float64(4.002204661626877), np.float64(10.834523213801894), np.float64(47.14974126884789), np.float64(7.0489381934290405), np.float64(27.723269857762745), np.float64(220.1375241116807), np.float64(356.8326949632889), np.float64(444.9780292248448), np.float64(40.14626077124395), np.float64(60.77289596839664), np.float64(1.2679927639573982), np.float64(930.0260699785583), np.float64(38.89354490658187), np.float64(38.255623894926494), np.float64(1.694481648793329), np.float64(1.275688784929681), np.float64(1.0235933025311792), np.float64(-0.15503464223304989), np.float64(1.51731308276224), np.float64(3.0115475858129064), np.float64(-0.30609997050828597), np.float64(0.9558538705069384), np.float64(-10.02186338523014), np.float64(10.1591459471308), np.float64(48.366201338977945), np.float64(47.883927319199344), np.float64(0.9402287185529821), np.float64(5.641997671553843), np.float64(74.1187619740261), np.float64(22.120842752032736)], Fitness: (np.float64(52.43667906202837),)
#
# Gerando a 85ª Explicação
#
# Por que o indivíduo foi classificado como: ['NORMAL'] ?
#
# Porque o seguintes nós foram percorridos para essa amostra:
# Nó 0: DISTEN = 0.804, condição testada: DISTEN <= 0.769 → NÃO SATISFEITA
# Nó 116: DFA  = 0.985, condição testada: DFA  <= 1.101 → SATISFEITA
# Nó 117: ATTEN = 1.327, condição testada: ATTEN <= 2.224 → SATISFEITA
# Nó 118: SYMB2UV = 28.940, condição testada: SYMB2UV <= 38.558 → SATISFEITA
# Nó 119: GUZIKS = 47.175, condição testada: GUZIKS <= 49.730 → SATISFEITA
# Nó 120: folha alcançada, o indivíduo é: ['NORMAL']
#
# Explicação para a 85ª instância de X_t {'Nó 0': 'DISTEN > 0.7687387764453888', 'Nó 116': 'DFA  <= 1.1014838218688965', 'Nó 117': 'ATTEN <= 2.2241759300231934', 'Nó 118': 'SYMB2UV <= 38.55814552307129', 'Nó 119': 'GUZIKS <= 49.72966003417969', 'Nó 120': 'Folha'}
#
# ⏱️ Tempo de execução da 85ª explicação: 165.52 segundos
#
# Gerando os Dados para a 86ª Explicação
#
# Indivíduo sendo explicado [9.2, 79.0, 59.0, 1.65, 99.0, 36.36363636363637, 54.7404, 4.8646, 36.4994, 48.082, 10.554, 35.197, 48.0404, 3.383, 13.3795, 327.315, 446.8009, 297.4068, 45.0224, 54.9776, 1.7618, 1017.147, 48.3167, 29.1, 1.2754, 1.7268, 1.4902, 0.6259, 2.4845, 4.419, 1.9624, 0.914, -12.1631, 10.9402, 47.5235, 47.4313, -0.5209, 17.057, 65.1593, 17.7837]
#
# Melhor indivíduo SSO: [np.float64(8.977350721441107), np.float64(79.55102404396973), np.float64(58.92634433032064), np.float64(1.7627257332451811), np.float64(98.65720762332613), np.float64(36.68739791200888), np.float64(56.81041983493405), np.float64(3.367730530197405), np.float64(36.507659452997075), np.float64(47.33506183528321), np.float64(11.460502060481911), np.float64(32.680692285644994), np.float64(48.373123508840195), np.float64(10.33965365602501), np.float64(13.932857886502823), np.float64(326.3408155736386), np.float64(446.19348373024116), np.float64(298.5659930678462), np.float64(47.868351387868216), np.float64(55.07448330305619), np.float64(1.5270347697199156), np.float64(1017.29104008386), np.float64(48.48964332417287), np.float64(28.98994701034396), np.float64(1.156533541582665), np.float64(2.95138979964485), np.float64(1.0399774911557271), np.float64(0.177651601787031), np.float64(2.587381503659403), np.float64(3.9075550659456226), np.float64(-2.4145622482601423), np.float64(1.3971028891421646), np.float64(-15.2935815489939), np.float64(9.632722099231136), np.float64(45.083464091869246), np.float64(47.343136325248466), np.float64(-0.05443363973384635), np.float64(16.65464932023097), np.float64(64.13276973338974), np.float64(16.04542661729764), 'APNEICO'], Fitness: (np.float64(152.46379247135195),)
float64(-0.41979369710794145), np.float64(2.4596785101063103), np.float64(3.5356005097337464), np.float64(1.421994072169904), np.float64(0.8822694802087606), np.float64(-6.329585193465205), np.float64(8.208938847528856), np.float64(47.7390320204218), np.float64(59.75513520071994), np.float64(-1.3858492693216182), np.float64(32.91071996963008), np.float64(48.208360676604904), np.float64(14.234017344524576), 'APNEICO'], Fitness: (np.float64(397.03334346478886),)
#
# Melhor indivíduo SDO: [np.float64(0.42169743576763624), np.float64(87.45310890102586), np.float64(69.93367684801117), np.float64(1.2640127123282932), np.float64(67.30507738884627), np.float64(24.283225709894104), np.float64(51.42270536535622), np.float64(14.648550667623688), np.float64(42.929907332468105), np.float64(36.48288638809838), np.float64(14.676065417939569), np.float64(43.525233748874214), np.float64(45.77216640682337), np.float64(2.242705465240667), np.float64(6.494067054738396), np.float64(230.67132168086832), np.float64(219.40575597487887), np.float64(81.5895156175699), np.float64(65.03431602054704), np.float64(34.78075573353699), np.float64(3.3887175276857837), np.float64(670.2678827055051), np.float64(27.451471000207462), np.float64(11.535226032038025), np.float64(3.024057995182885), np.float64(2.9542770330677097), np.float64(0.32847495710380803), np.float64(-0.13623916467409553), np.float64(2.0076583162159554), np.float64(-1.5554133708622266), np.float64(1.8156800438617398), np.float64(0.8652921344779672), np.float64(-5.086171590922719), np.float64(9.76301198579269), np.float64(49.218336267350814), np.float64(48.96333817859589), np.float64(0.9497527971147122), np.float64(36.42026420270497), np.float64(48.33022062029294), np.float64(14.392768581278329)], Fitness: (np.float64(755.6262202451944),)
#
# Gerando a 87ª Explicação
#
# Por que o indivíduo foi classificado como: ['NORMAL'] ?
#
# Porque o seguintes nós foram percorridos para essa amostra:
# Nó 0: PHASEEN = 0.905, condição testada: PHASEEN <= 0.910 → SATISFEITA
# Nó 1: T90 = 0.000, condição testada: T90 <= 1.959 → SATISFEITA
# Nó 2: IDADE = 71.000, condição testada: IDADE <= 67.848 → NÃO SATISFEITA
# Nó 10: DFA  = 1.383, condição testada: DFA  <= 1.449 → SATISFEITA
# Nó 11: SAMPEN = 1.411, condição testada: SAMPEN <= 4.005 → SATISFEITA
# Nó 12: W1 = 40.903, condição testada: W1 <= 33.530 → NÃO SATISFEITA
# Nó 14: AC = -6.233, condição testada: AC <= -3.933 → SATISFEITA
# Nó 15: FUZZYEN = 1.114, condição testada: FUZZYEN <= 4.255 → SATISFEITA
# Nó 16: PIP = 49.749, condição testada: PIP <= 53.366 → SATISFEITA
# Nó 17: RMSSD = 11.195, condição testada: RMSSD <= 4.360 → NÃO SATISFEITA
# Nó 19: VLFABS = 229.901, condição testada: VLFABS <= 226.992 → NÃO SATISFEITA
# Nó 23: folha alcançada, o indivíduo é: ['NORMAL']
#
# Explicação para a 87ª instância de X_t {'Nó 0': 'PHASEEN <= 0.9095212519168854', 'Nó 1': 'T90 <= 1.9594878554344177', 'Nó 2': 'IDADE > 67.84797668457031', 'Nó 10': 'DFA  <= 1.4485039114952087', 'Nó 11': 'SAMPEN <= 4.00493597984314', 'Nó 12': 'W1 > 33.52961540222168', 'Nó 14': 'AC <= -3.9325066804885864', 'Nó 15': 'FUZZYEN <= 4.2545071840286255', 'Nó 16': 'PIP <= 53.36624717712402', 'Nó 17': 'RMSSD > 4.3597564697265625', 'Nó 19': 'VLFABS > 226.9916534423828', 'Nó 23': 'Folha'}
#
# Gerando a 88ª Explicação
#
# Por que o indivíduo foi classificado como: ['NORMAL'] ?
#
# Porque o seguintes nós foram percorridos para essa amostra:
# Nó 0: PHASEEN = 0.903, condição testada: PHASEEN <= 0.929 → SATISFEITA
# Nó 1: SYMB2UV = 19.806, condição testada: SYMB2UV <= 17.970 → NÃO SATISFEITA
# Nó 5: DFA  = 0.912, condição testada: DFA  <= 1.396 → SATISFEITA
# Nó 6: folha alcançada, o indivíduo é: ['NORMAL']
#
# Explicação para a 88ª instância de X_t {'Nó 0': 'PHASEEN <= 0.9290055334568024', 'Nó 1': 'SYMB2UV > 17.969992637634277', 'Nó 5': 'DFA  <= 1.3955723643302917', 'Nó 6': 'Folha'}
#
# ⏱️ Tempo de execução da 88ª explicação: 164.35 segundos
#
# ✅ Tempo total de execução: 14911.96 segundos

# %% [markdown]
# ## Nestes testes as explicações dos erros e dos acertos foram salvas na mesma pasta e são separados de acordo com os indices do df_acertos e erros, diferente dos outros testes que as explicações são geradas separadamente sobre o df_erros e sobre o df_acertos

# %% [markdown]
# # ACERTOS (65)

# %%
X_t88 = X_t.reset_index(drop=True)
X_t88
# Out:
#       T90  SATMIN  IDADE    ALTURA        PESO        IMC      PIP       W0  \
# 0    0.00      90     42  1.610000  108.000000  41.665059  54.4808   6.0207
# 1    2.40      85     54  1.560000   77.300000  31.763642  59.7655   5.2408
# 2    2.00      82     53  1.640000   65.000000  24.167162  58.2716   5.4463
# 3    9.20      70     65  1.650000  122.000000  44.811754  59.9173   1.7589
# 4    0.00      91     66  1.649234   89.262007  32.817260  47.7825  24.3318
# ..    ...     ...    ...       ...         ...        ...      ...      ...
# 83  57.50      76     50  1.650000   77.000000  28.282828  56.8099   4.1040
# 84   0.66      77     38  1.710000  112.000000  38.302384  58.8936   1.8790
# 85   9.20      79     59  1.650000   99.000000  36.363636  54.7404   4.8646
# 86   0.00      89     71  1.550000   68.000000  28.303850  49.7488  12.1526
# 87   0.00      91     18  1.450000   58.100000  27.633769  63.4614   1.1389
#
#          W1       W2  ...   ATTEN  PHASEEN       AC       DC   PORTAS  \
# 0   38.3577  41.8240  ...  2.4321   0.9088  -6.1145   6.4501  51.3422
# 1   30.7866  43.3670  ...  2.3805   0.9062  -6.0373   6.1587  50.8726
# 2   29.4046  50.0357  ...  2.0785   0.9211  -7.5442   7.9502  51.4894
# 3   28.2187  58.5742  ...  1.6449   0.9062  -9.5779   6.8927  48.0135
# 4   26.6360  30.5093  ...  3.2938   0.8534  -7.1254  10.2476  57.5344
# ..      ...      ...  ...     ...      ...      ...      ...      ...
# 83  33.3440  50.5588  ...  1.9252   0.9079 -13.5336  12.5032  48.3607
# 84  22.8335  72.0267  ...  1.3269   0.9037 -12.1727  10.6368  46.8407
# 85  36.4994  48.0820  ...  1.9624   0.9140 -12.1631  10.9402  47.5235
# 86  40.9029  32.5342  ...  2.8252   0.9049  -6.2331   9.2372  50.1037
# 87  28.6466  48.9592  ...  1.9446   0.9027  -4.7810   5.9880  54.5138
#
#      GUZIKS  EHLERS    BIN0V    BIN1V    BIN2V
# 0   52.2414  0.4297  27.6741  59.3422  12.9837
# 1   51.4137  0.4595  23.5269  56.0213  20.4518
# 2   51.6891  0.4140  17.6156  60.0317  22.3527
# 3   48.4821 -0.1614   9.4193  68.5894  21.9913
# 4   61.9283  3.2136  44.2501  35.7581  19.9918
# ..      ...     ...      ...      ...      ...
# 83  48.9202 -0.0542  15.4449  62.7220  21.8331
# 84  47.1754 -0.4222   4.8753  73.8015  21.3232
# 85  47.4313 -0.5209  17.0570  65.1593  17.7837
# 86  50.3292  0.1274  36.9561  48.3929  14.6509
# 87  56.4734  1.2044  13.8953  61.3030  24.8018
#
# [88 rows x 40 columns]

# %%
y_t88 = y_t.reset_index(drop=True)
y_t88
# Out:
# 0      NORMAL
# 1     APNEICO
# 2      NORMAL
# 3     APNEICO
# 4     APNEICO
#        ...
# 83    APNEICO
# 84    APNEICO
# 85    APNEICO
# 86    APNEICO
# 87     NORMAL
# Name: CLASSE, Length: 88, dtype: object

# %%
y_series = pd.Series(y_t88, index=X_t88.index)  
y_pred_series = pd.Series(predict, index=X_t88.index)  

#Criando uma máscara de erro alinhada com o índice de X
mask_acertos = y_series == y_pred_series  

#Selecionando as instâncias mal classificadas
df_acertos = X_t88.loc[mask_acertos].copy()  

#Adicionando as classes real e prevista ao DataFrame de erros
df_acertos['Classe_Real'] = y_series[mask_acertos].values
df_acertos['Classe_Prevista'] = y_pred_series[mask_acertos].values

print(df_acertos.shape)
df_acertos
# Out:
# (64, 42)
#       T90  SATMIN  IDADE    ALTURA        PESO        IMC      PIP       W0  \
# 1    2.40      85     54  1.560000   77.300000  31.763642  59.7655   5.2408
# 2    2.00      82     53  1.640000   65.000000  24.167162  58.2716   5.4463
# 3    9.20      70     65  1.650000  122.000000  44.811754  59.9173   1.7589
# 4    0.00      91     66  1.649234   89.262007  32.817260  47.7825  24.3318
# 5   98.40      64     68  1.500000   55.000000  24.444444  46.5864  18.1349
# ..    ...     ...    ...       ...         ...        ...      ...      ...
# 81  12.10      75     42  1.750000  126.000000  41.142857  61.3726   6.5033
# 82  72.12      78     74  1.860000  103.000000  29.772228  58.8783   3.8066
# 83  57.50      76     50  1.650000   77.000000  28.282828  56.8099   4.1040
# 85   9.20      79     59  1.650000   99.000000  36.363636  54.7404   4.8646
# 87   0.00      91     18  1.450000   58.100000  27.633769  63.4614   1.1389
#
#          W1       W2  ...       AC       DC   PORTAS   GUZIKS  EHLERS  \
# 1   30.7866  43.3670  ...  -6.0373   6.1587  50.8726  51.4137  0.4595
# 2   29.4046  50.0357  ...  -7.5442   7.9502  51.4894  51.6891  0.4140
# 3   28.2187  58.5742  ...  -9.5779   6.8927  48.0135  48.4821 -0.1614
# 4   26.6360  30.5093  ...  -7.1254  10.2476  57.5344  61.9283  3.2136
# 5   36.0288  33.7538  ...  -8.2082   8.2682  50.3578  51.5395  0.4637
# ..      ...      ...  ...      ...      ...      ...      ...     ...
# 81  16.7658  63.0172  ... -25.9128  26.6190  51.0259  50.9400  0.2838
# 82  30.6244  50.6932  ...  -5.7719   5.6918  49.5567  48.8569 -0.2741
# 83  33.3440  50.5588  ... -13.5336  12.5032  48.3607  48.9202 -0.0542
# 85  36.4994  48.0820  ... -12.1631  10.9402  47.5235  47.4313 -0.5209
# 87  28.6466  48.9592  ...  -4.7810   5.9880  54.5138  56.4734  1.2044
#
#       BIN0V    BIN1V    BIN2V  Classe_Real  Classe_Prevista
# 1   23.5269  56.0213  20.4518      APNEICO          APNEICO
# 2   17.6156  60.0317  22.3527       NORMAL           NORMAL
# 3    9.4193  68.5894  21.9913      APNEICO          APNEICO
# 4   44.2501  35.7581  19.9918      APNEICO          APNEICO
# 5   40.2026  47.4331  12.3644      APNEICO          APNEICO
# ..      ...      ...      ...          ...              ...
# 81  12.1426  55.7329  32.1245      APNEICO          APNEICO
# 82  14.0599  60.5869  25.3532      APNEICO          APNEICO
# 83  15.4449  62.7220  21.8331      APNEICO          APNEICO
# 85  17.0570  65.1593  17.7837      APNEICO          APNEICO
# 87  13.8953  61.3030  24.8018       NORMAL           NORMAL
#
# [64 rows x 42 columns]

# %%
import os
import pandas as pd
from collections import Counter
import re

#Caminho da pasta onde estão os arquivos de explicação
pasta_explicacoes = "exp_final fs"

todos_os_atributos = []

#Índices dos acertos estabelecidos previamente
indices_acertos = df_acertos.index.tolist()

for idx in indices_acertos:
    nome_arquivo = f"explicacao_final_amostra_{idx}.txt"
    caminho_arquivo = os.path.join(pasta_explicacoes, nome_arquivo)
    
    if os.path.exists(caminho_arquivo):
        with open(caminho_arquivo, "r", encoding="utf-8") as f:
            linhas = f.readlines()
        
        for linha in linhas:
            # Pula a linha se for uma folha (sem condição)
            if "Folha" in linha:
                continue
            # Extrai o nome do atributo antes do operador
            match = re.search(r'Nó \d+: ([A-Z0-9_]+) [<>=]', linha)
            if match:
                atributo = match.group(1)
                todos_os_atributos.append(atributo)

#Conta frequência dos atributos
attribute_counts = Counter(todos_os_atributos)

#Converte em DataFrame
attribute_counts_df = pd.DataFrame(attribute_counts.items(), columns=['Atributo', 'Frequência'])
attribute_counts_df = attribute_counts_df.sort_values(by='Frequência', ascending=False)

#Salva um arquivo CSV
attribute_counts_df.to_csv('LOREfs Contagem de Atributos (ACERTOS).csv', index=False)

print("\nFrequência dos Atributos (ACERTOS):")
print(attribute_counts_df)
# Out:
# Frequência dos Atributos (ACERTOS):
#    Atributo  Frequência
# 2   PHASEEN          30
# 8     ATTEN          22
# 0       T90          20
# 17   DISTEN          13
# 22      IMC          13
# 10   DISPEN          11
# 12   PORTAS           9
# 26       W0           9
# 7    SAMPEN           8
# 4     LFABS           7
# 3      LFNU           6
# 32  SYMB2LV           6
# 35   PERMEN           6
# 20       AC           6
# 21    BIN2V           6
# 29    RMSSD           5
# 13       W3           5
# 1     IDADE           5
# 15  SYMB2UV           5
# 27       DC           5
# 34   SYMB1V           5
# 36   EHLERS           5
# 5      SDNN           4
# 16      PIP           4
# 28  FUZZYEN           4
# 31       W2           4
# 23   ALTURA           4
# 19       W1           4
# 37     LFHF           3
# 24     HFNU           3
# 14   MEANRR           3
# 30     PESO           3
# 6     BIN0V           2
# 9    GUZIKS           2
# 11   SATMIN           2
# 33   VLFABS           2
# 25   SYMB0V           2
# 38    HFABS           2
# 18    BIN1V           1

# %% [markdown]
# # ERROS (23)

# %%
y_series = pd.Series(y_t88, index=X_t88.index)  
y_pred_series = pd.Series(predict, index=X_t88.index)  

#Criando uma máscara de erro alinhada com o índice de X
mask_erros = y_series != y_pred_series  

#Selecionando as instâncias mal classificadas
df_erros = X_t88.loc[mask_erros].copy()  

#Adicionando as classes real e prevista ao DataFrame de erros
df_erros['Classe_Real'] = y_series[mask_erros].values
df_erros['Classe_Prevista'] = y_pred_series[mask_erros].values

print(df_erros.shape)
df_erros
# Out:
# (24, 42)
#       T90  SATMIN  IDADE    ALTURA        PESO        IMC      PIP       W0  \
# 0    0.00      90     42  1.610000  108.000000  41.665059  54.4808   6.0207
# 9   89.60      79     57  1.600000   94.000000  36.718750  54.4633   7.8556
# 10   0.90      88     52  1.550000   68.000000  28.303850  52.1014   6.9298
# 23  20.70      86     59  1.700000   92.000000  31.833910  57.9490   6.0096
# 25   4.60      83     59  1.649234   89.262007  32.817260  62.6354   5.1821
# 27   2.10      88     57  1.700000   81.500000  28.200692  52.9537   8.6130
# 28  98.00      82     78  1.520000   50.000000  21.641274  77.6891   1.3591
# 29  13.70      81     60  1.600000   71.000000  27.734375  49.5573   5.7055
# 31   0.50      82     67  1.840000  108.000000  31.899811  54.8186   3.2005
# 34  47.30      79     50  1.690000  140.000000  49.017892  70.0063   1.0088
# 37   3.24      84     79  1.720000   68.450000  23.137507  55.0497   1.3982
# 40   0.20      87     55  1.650000   66.300000  24.352617  65.1422   2.3893
# 49   0.00      91     38  1.750000   84.000000  27.428571  43.3087  16.9028
# 54   1.40      83     46  1.540000  120.000000  50.598752  60.3252   1.2393
# 56   7.46      67     68  1.680000   81.900000  29.017857  47.6673   2.4734
# 57  10.00      79     37  1.680000  115.000000  40.745465  68.7781   0.6590
# 63  97.70      75     53  1.560000  100.000000  41.091387  48.9243   2.3820
# 64   0.00      90     50  1.720000   81.000000  27.379665  55.7424  11.9029
# 65   0.00      91     20  1.730000   89.000000  29.737044  47.8898   7.2261
# 68   2.70      85     66  1.740000   94.500000  31.212842  68.0291   2.0568
# 69   2.40      85     65  1.650000   70.000000  25.711662  51.9238   2.2666
# 76   5.40      83     30  1.660000  102.100000  37.051822  49.8926   3.1941
# 84   0.66      77     38  1.710000  112.000000  38.302384  58.8936   1.8790
# 86   0.00      89     71  1.550000   68.000000  28.303850  49.7488  12.1526
#
#          W1       W2  ...       AC       DC   PORTAS   GUZIKS    EHLERS  \
# 0   38.3577  41.8240  ...  -6.1145   6.4501  51.3422  52.2414  0.429700
# 9   38.4967  36.0125  ...  -6.2748   4.3010  46.0335  42.3945 -1.331100
# 10  43.7267  35.4601  ...  -8.9557   5.7432  52.0487  52.0334  0.342200
# 23  28.7467  50.5872  ...  -8.0870   8.2654  49.9237  49.6764 -0.060900
# 25  26.5503  43.4533  ...  -3.5383   4.1281  52.1756  53.5385  0.725200
# 86  36.9561  48.3929  14.6509      APNEICO           NORMAL
#
# [24 rows x 42 columns]

# %%
import os
import pandas as pd
from collections import Counter
import re

#Caminho da pasta onde estão os arquivos de explicação
pasta_explicacoes = "exp_final fs"

todos_os_atributos = []

#Índices dos erros definidos no df_erros
indices_erros = df_erros.index.tolist()

for idx in indices_erros:
    nome_arquivo = f"explicacao_final_amostra_{idx}.txt"
    caminho_arquivo = os.path.join(pasta_explicacoes, nome_arquivo)
    
    if os.path.exists(caminho_arquivo):
        with open(caminho_arquivo, "r", encoding="utf-8") as f:
            linhas = f.readlines()
        
        for linha in linhas:
            #Pula a linha se for uma folha (sem condição)
            if "Folha" in linha:
                continue
            #Extrai o nome do atributo antes do operador
            match = re.search(r'Nó \d+: ([A-Z0-9_]+) [<>=]', linha)
            if match:
                atributo = match.group(1)
                todos_os_atributos.append(atributo)
    else:
        print(f" Arquivo {nome_arquivo} não encontrado.")

#Conta frequência dos atributos
attribute_counts = Counter(todos_os_atributos)

#Converte em DataFrame
attribute_counts_df = pd.DataFrame(attribute_counts.items(), columns=['Atributo', 'Frequência'])
attribute_counts_df = attribute_counts_df.sort_values(by='Frequência', ascending=False)

#Salva o CSV
attribute_counts_df.to_csv('LOREfs Contagem de Atributos (ERROS).csv', index=False)

#Mostra na tela
print("\n Frequência dos Atributos (ERROS):")
print(attribute_counts_df)
# Out:
#  Frequência dos Atributos (ERROS):
#    Atributo  Frequência
# 0       T90          16
# 8   PHASEEN          11
# 14   DISPEN           9
# 1     ATTEN           9
# 2    SAMPEN           8
# 15   DISTEN           7
# 7    EHLERS           6
# 6   SYMB2UV           6
# 13  SYMB2LV           5
# 9   FUZZYEN           5
# 21   GUZIKS           4
# 19   VLFABS           4
# 17      PIP           4
# 11      IMC           4
# 18    RMSSD           3
# 5    PORTAS           3
# 4     BIN1V           3
# 12    IDADE           3
# 34       W1           3
# 32     LFNU           2
# 20       DC           2
# 16       AC           2
# 30       W2           2
# 25   ALTURA           2
# 29       W3           2
# 27     SDNN           2
# 36     PESO           2
# 3    MEANRR           1
# 10    BIN0V           1
# 22   SATMIN           1
# 28   SYMB1V           1
# 26    HFABS           1
# 23   PERMEN           1
# 24   SYMB0V           1
# 33    BIN2V           1
# 31     HFNU           1
# 35       W0           1
# 37     LFHF           1

# %% [markdown]
# # TODAS AS EXPLICAÇÕES

# %%
import os
import pandas as pd
from collections import Counter
import re

# Caminho da pasta onde estão os arquivos
pasta_explicacoes = "exp_final fs"

# Lista para guardar todos os atributos encontrados
todos_os_atributos = []

# Loop pelos arquivos
for nome_arquivo in os.listdir(pasta_explicacoes):
    if nome_arquivo.startswith("explicacao_final_amostra_") and nome_arquivo.endswith(".txt"):
        caminho_arquivo = os.path.join(pasta_explicacoes, nome_arquivo)
        
        with open(caminho_arquivo, "r", encoding="utf-8") as f:
            linhas = f.readlines()
        
        for linha in linhas:
            # Pula a linha se for uma folha (sem condição)
            if "Folha" in linha:
                continue
            # Extrai o nome do atributo (assume que ele vem após ': ' e antes do operador)
            match = re.search(r'Nó \d+: ([A-Z0-9_]+) [<>=]', linha)
            if match:
                atributo = match.group(1)
                todos_os_atributos.append(atributo)

# Conta frequência de cada atributo
attribute_counts = Counter(todos_os_atributos)

# Converte em DataFrame
attribute_counts_df = pd.DataFrame(attribute_counts.items(), columns=['Atributo', 'Frequência'])
attribute_counts_df = attribute_counts_df.sort_values(by='Frequência', ascending=False)

# Salva o resultado em CSV
attribute_counts_df.to_csv('LOREfs Contagem de Atributos (TODOS).csv', index=False)

print("\n Frequência dos Atributos (TODOS OS EXEMPLOS DE TESTE):")
print(attribute_counts_df)
# Out:
#  Frequência dos Atributos (TODOS OS EXEMPLOS DE TESTE):
#    Atributo  Frequência
# 7   PHASEEN          41
# 0       T90          36
# 1     ATTEN          31
# 13   DISPEN          20
# 23   DISTEN          20
# 19      IMC          17
# 2    SAMPEN          16
# 5    PORTAS          12
# 15   EHLERS          11
# 32  SYMB2LV          11
# 14  SYMB2UV          11
# 17       W0          10
# 22  FUZZYEN           9
# 6     IDADE           8
# 27    RMSSD           8
# 8      LFNU           8
# 31      PIP           8
# 25       AC           8
# 37       W1           7
# 35   PERMEN           7
# 21       W3           7
# 9     LFABS           7
# 18       DC           7
# 24    BIN2V           7
# 33   VLFABS           6
# 29       W2           6
# 34   SYMB1V           6
# 10     SDNN           6
# 20   ALTURA           6
# 12   GUZIKS           6
# 28     PESO           5
# 3    MEANRR           4
# 4     BIN1V           4
# 38     LFHF           4
# 26     HFNU           4
# 16   SYMB0V           3
# 11    BIN0V           3
# 30   SATMIN           3
# 36    HFABS           3

# %% [markdown]
# # ATRIBUTOS MAIS FREQUENTES NA PRIMEIRA, SEGUNDA, TERCEIRA, QUARTA E QUINTA POSIÇÃO

# %%
#ERROS
import os
import pandas as pd
from collections import Counter
import re

# Caminho da pasta onde estão os arquivos de explicação
pasta_explicacoes = "exp_final fs"

# Índices dos erros
indices_erros = df_erros.index.tolist()

# Dicionários para armazenar os atributos por posição
posicoes = {
    1: [],
    2: [],
    3: [],
    4: [],
    5: []
}

# Loop pelos índices
for idx in indices_erros:
    nome_arquivo = f"explicacao_final_amostra_{idx}.txt"
    caminho_arquivo = os.path.join(pasta_explicacoes, nome_arquivo)
    
    if os.path.exists(caminho_arquivo):
        with open(caminho_arquivo, "r", encoding="utf-8") as f:
            linhas = f.readlines()

        atributos_na_ordem = []
        for linha in linhas:
            if "Folha" in linha:
                continue
            match = re.search(r'Nó \d+: ([A-Z0-9_]+) [<>=]', linha)
            if match:
                atributo = match.group(1)
                atributos_na_ordem.append(atributo)

        # Armazena os atributos nas posições desejadas
        for pos in posicoes:
            if len(atributos_na_ordem) >= pos:
                posicoes[pos].append(atributos_na_ordem[pos - 1])
    else:
        print(f"Arquivo {nome_arquivo} não encontrado.")

# Cria contadores para cada posição
contagens_por_posicao = {}
for pos, atributos in posicoes.items():
    contagens = Counter(atributos)
    df_contagem = pd.DataFrame(contagens.items(), columns=['Atributo', 'Frequência'])
    df_contagem = df_contagem.sort_values(by='Frequência', ascending=False)
    contagens_por_posicao[pos] = df_contagem

    # Exibe na tela
    print(f"\n🔹 Atributos mais frequentes na posição {pos}:")
    print(df_contagem.head())
# Out:
# 🔹 Atributos mais frequentes na posição 1:
#   Atributo  Frequência
# 1  PHASEEN           7
# 0      T90           5
# 4   DISTEN           3
# 2      IMC           2
# 3   DISPEN           2
#
# 🔹 Atributos mais frequentes na posição 2:
#   Atributo  Frequência
# 4      T90           6
# 8   DISPEN           4
# 0    ATTEN           3
# 5   DISTEN           2
# 3  PHASEEN           2
#
# 🔹 Atributos mais frequentes na posição 3:
#   Atributo  Frequência
# 0   SAMPEN           4
# 3  SYMB2UV           3
# 1   EHLERS           2
# 6  PHASEEN           2
# 7  SYMB2LV           2
#
# 🔹 Atributos mais frequentes na posição 4:
#   Atributo  Frequência
# 1    ATTEN           2
# 2      T90           2
# 6   GUZIKS           2
# 0   MEANRR           1
# 3    IDADE           1
#
# 🔹 Atributos mais frequentes na posição 5:
#    Atributo  Frequência
# 11       W1           3
# 1   FUZZYEN           1
# 0     BIN1V           1
# 3       PIP           1
# 4        DC           1

# %%
#ACERTOS
import os
import pandas as pd
from collections import Counter
import re

# Caminho da pasta onde estão os arquivos de explicação
pasta_explicacoes = "exp_final fs"

# Índices dos erros
indices_acertos = df_acertos.index.tolist()

# Dicionários para armazenar os atributos por posição
posicoes = {
    1: [],
    2: [],
    3: [],
    4: [],
    5: []
}

# Loop pelos índices
for idx in indices_acertos:
    nome_arquivo = f"explicacao_final_amostra_{idx}.txt"
    caminho_arquivo = os.path.join(pasta_explicacoes, nome_arquivo)
    
    if os.path.exists(caminho_arquivo):
        with open(caminho_arquivo, "r", encoding="utf-8") as f:
            linhas = f.readlines()

        atributos_na_ordem = []
        for linha in linhas:
            if "Folha" in linha:
                continue
            match = re.search(r'Nó \d+: ([A-Z0-9_]+) [<>=]', linha)
            if match:
                atributo = match.group(1)
                atributos_na_ordem.append(atributo)

        # Armazena os atributos nas posições desejadas
        for pos in posicoes:
            if len(atributos_na_ordem) >= pos:
                posicoes[pos].append(atributos_na_ordem[pos - 1])
    else:
        print(f"Arquivo {nome_arquivo} não encontrado.")

# Cria contadores para cada posição
contagens_por_posicao = {}
for pos, atributos in posicoes.items():
    contagens = Counter(atributos)
    df_contagem = pd.DataFrame(contagens.items(), columns=['Atributo', 'Frequência'])
    df_contagem = df_contagem.sort_values(by='Frequência', ascending=False)
    contagens_por_posicao[pos] = df_contagem
    
    #Exibe na tela
    print(f"\n🔹 Atributos mais frequentes na posição {pos}:")
    print(df_contagem.head())
# Out:
# 🔹 Atributos mais frequentes na posição 1:
#   Atributo  Frequência
# 1  PHASEEN          18
# 0      T90           9
# 3   DISPEN           7
# 5       DC           4
# 6    ATTEN           3
#
# 🔹 Atributos mais frequentes na posição 2:
#    Atributo  Frequência
# 2     ATTEN           9
# 4   PHASEEN           7
# 1    DISTEN           7
# 13      T90           3
# 12       W0           3
#
# 🔹 Atributos mais frequentes na posição 3:
#    Atributo  Frequência
# 8     ATTEN           5
# 4       T90           4
# 0   PHASEEN           3
# 7       IMC           3
# 13   PERMEN           3
#
# 🔹 Atributos mais frequentes na posição 4:
#    Atributo  Frequência
# 1    PORTAS           5
# 4        W0           4
# 2     ATTEN           2
# 0      LFNU           2
# 10    IDADE           2
#
# 🔹 Atributos mais frequentes na posição 5:
#    Atributo  Frequência
# 0     LFABS           3
# 1        W3           2
# 6       IMC           2
# 4    PORTAS           2
# 16     LFHF           2

# %%
import os
import re
import numpy as np

pasta_explicacoes = "exp_premissas fs"
classes_extraidas = []

# Regex para extrair a classe
padrao_classe = re.compile(r"folha alcançada, o indivíduo é: \['(.*?)'\]")

# Função para extrair o número do nome do arquivo
def extrai_numero(nome):
    return int(re.search(r'(\d+)', nome).group(1))

# Seleciona e ordena os arquivos corretamente
arquivos = [f for f in os.listdir(pasta_explicacoes) 
            if f.startswith("explicacao_nos_amostra_") and f.endswith(".txt")]
arquivos_ordenados = sorted(arquivos, key=extrai_numero)

# Processa cada arquivo na ordem correta
for nome_arquivo in arquivos_ordenados:
    caminho_arquivo = os.path.join(pasta_explicacoes, nome_arquivo)

    with open(caminho_arquivo, "r", encoding="utf-8") as f:
        conteudo = f.read()

    match = padrao_classe.search(conteudo)
    if match:
        classe = match.group(1)
    else:
        classe = "DESCONHECIDO"

    classes_extraidas.append(classe)

classes_DT = np.array(classes_extraidas)
print(classes_DT)

classes_RF = predict
print(classes_RF)
#print(classes_iniciais)
# Out:
# ['NORMAL' 'APNEICO' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO' 'APNEICO'
#  'APNEICO' 'NORMAL' 'APNEICO' 'NORMAL' 'APNEICO' 'NORMAL' 'APNEICO'
#  'APNEICO' 'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO' 'APNEICO'
#  'APNEICO' 'APNEICO' 'APNEICO' 'APNEICO' 'NORMAL' 'APNEICO' 'APNEICO'
#  'APNEICO' 'NORMAL' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO' 'NORMAL'
#  'APNEICO' 'APNEICO' 'NORMAL' 'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL'
#  'APNEICO' 'APNEICO' 'APNEICO' 'NORMAL' 'NORMAL' 'APNEICO' 'NORMAL'
#  'NORMAL' 'APNEICO' 'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO'
#  'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO' 'NORMAL'
#  'APNEICO' 'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO'
#  'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO' 'NORMAL' 'APNEICO'
#  'APNEICO' 'NORMAL' 'APNEICO' 'NORMAL' 'APNEICO' 'NORMAL' 'NORMAL'
#  'NORMAL' 'APNEICO' 'NORMAL' 'NORMAL']
# ['APNEICO' 'APNEICO' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO' 'APNEICO'
#  'APNEICO' 'NORMAL' 'APNEICO' 'NORMAL' 'APNEICO' 'NORMAL' 'APNEICO'
#  'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO'
#  'APNEICO' 'APNEICO' 'APNEICO' 'NORMAL' 'NORMAL' 'APNEICO' 'APNEICO'
#  'APNEICO' 'NORMAL' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO' 'APNEICO'
#  'APNEICO' 'APNEICO' 'NORMAL' 'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL'
#  'APNEICO' 'APNEICO' 'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO'
#  'NORMAL' 'APNEICO' 'NORMAL' 'NORMAL' 'APNEICO' 'NORMAL' 'APNEICO'
#  'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO' 'NORMAL'
#  'APNEICO' 'NORMAL' 'NORMAL' 'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO' 'NORMAL'
#  'NORMAL' 'NORMAL' 'NORMAL' 'APNEICO' 'NORMAL' 'APNEICO' 'APNEICO'
#  'APNEICO' 'APNEICO' 'NORMAL' 'APNEICO' 'APNEICO' 'APNEICO' 'NORMAL'
#  'APNEICO' 'NORMAL' 'NORMAL']

# %%
def calcular_acuracia(classes_reais, classes_preditas):
    # Se forem dicionários, pega os valores
    if isinstance(classes_reais, dict):
        classes_reais = list(classes_reais.values())
    if isinstance(classes_preditas, dict):
        classes_preditas = list(classes_preditas.values())

    # Garante que são arrays para facilitar a comparação
    import numpy as np
    reais = np.array(classes_reais)
    preditas = np.array(classes_preditas)

    # Verifica se os tamanhos batem
    if reais.shape != preditas.shape:
        raise ValueError("As listas/dicionários têm tamanhos diferentes.")

    # Calcula a acurácia
    acertos = np.sum(reais == preditas)
    total = len(reais)
    acuracia = acertos / total
    print(acertos)
    return acuracia
